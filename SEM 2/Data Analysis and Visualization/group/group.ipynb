# %% [markdown]
# ## 1. Find the Descriptive Statistics for the all four Dataset and <br>
# ## 2. Plot the scatter plot and linear regression line for each datasets

# %% [markdown]
# #### Importing Nessecary Libraries

# %%
import warnings
warnings.filterwarnings("ignore")  #this helps filter out any unnessecary warnings, So you can always import it first when you are working on project whether class or personnal

# %%
import pandas as pd  #data manipulation
import numpy as np #numeric python
import matplotlib.pyplot as plt  #visualization
import seaborn as sns  # interactive and advanced visualization
from scipy import stats

# %% [markdown]
# ## `Method two is better its direct to the point, no need of recreating the dictionary or dataset`

# %% [markdown]
# ## Method One

# %% [markdown]
# ### Defining the Variables

# %%
# Defining the variables with several data points
x1 = np.array([10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5])
x2 = np.array([10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5])
x3 = np.array([10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5])
x4 = np.array([8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8])

y1 = np.array([8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68])
y2 = np.array([9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74])
y3 = np.array([7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73])
y4 = np.array([6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89])

#the above arrays from x1 to y4 are organized into a dictionary (datasets)
datasets = {'x1': x1, 'x2': x2, 'x3': x3, 'x4': x4, 'y1': y1, 'y2': y2, 'y3': y3, 'y4': y4}

# Convert the above dictionary into a DataFrame (df)
df = pd.DataFrame(datasets)

# %% [markdown]
# ### Calculating Descriptive Statistics

# %%
descriptive_stats = df.describe()

# %%
print("Descriptive Statistics:\n\n", descriptive_stats)
# Out:
# Descriptive Statistics:
#
#                x1         x2         x3         x4         y1         y2  \
# count  11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean    9.000000   9.000000   9.000000   9.000000   7.500909   7.500909
# std     3.316625   3.316625   3.316625   3.316625   2.031568   2.031657
# min     4.000000   4.000000   4.000000   8.000000   4.260000   3.100000
# 25%     6.500000   6.500000   6.500000   8.000000   6.315000   6.695000
# 50%     9.000000   9.000000   9.000000   8.000000   7.580000   8.140000
# 75%    11.500000  11.500000  11.500000   8.000000   8.570000   8.950000
# max    14.000000  14.000000  14.000000  19.000000  10.840000   9.260000
#
#               y3         y4
# count  11.000000  11.000000
# mean    7.500000   7.500909
# std     2.030424   2.030579
# min     5.390000   5.250000
# 25%     6.250000   6.170000
# 50%     7.110000   7.040000
# 75%     7.980000   8.190000
# max    12.740000  12.500000

# %% [markdown]
# ### Calculating correlations

# %%
correlations = df.corr()

# %%
print("\nCorrelations:\n", correlations)
# Out:
# Correlations:
#            x1        x2        x3        x4        y1        y2        y3  \
# x1  1.000000  1.000000  1.000000 -0.500000  0.816421  0.816237  0.816287
# x2  1.000000  1.000000  1.000000 -0.500000  0.816421  0.816237  0.816287
# x3  1.000000  1.000000  1.000000 -0.500000  0.816421  0.816237  0.816287
# x4 -0.500000 -0.500000 -0.500000  1.000000 -0.529093 -0.718437 -0.344661
# y1  0.816421  0.816421  0.816421 -0.529093  1.000000  0.750005  0.468717
# y2  0.816237  0.816237  0.816237 -0.718437  0.750005  1.000000  0.587919
# y3  0.816287  0.816287  0.816287 -0.344661  0.468717  0.587919  1.000000
# y4 -0.314047 -0.314047 -0.314047  0.816521 -0.489116 -0.478095 -0.155472
#
#           y4
# x1 -0.314047
# x2 -0.314047
# x3 -0.314047
# x4  0.816521
# y1 -0.489116
# y2 -0.478095
# y3 -0.155472
# y4  1.000000

# %% [markdown]
# ### Calculate linear regression parameters for each dataset

# %%
regression_results = {}  #Initialize Dictionary for Regression Results

#Perform Linear Regression for Each Dataset
for i in range(1, 5):
    slope, intercept, r_value, p_value, std_err = stats.linregress(df[f'x{i}'], df[f'y{i}'])
    
    regression_results[f'regression_{i}'] = {
        'slope': slope,
        'intercept': intercept,
        'r_value': r_value,
        'p_value': p_value,
        'std_err': std_err
    }

# %% [markdown]
# slope:  The slope of the regression line. <br>
# intercept:  The y-intercept of the regression line.<br>
# r_value:  Correlation coefficient.<br>
# p_value:  p-value for a hypothesis test whose null hypothesis is that the slope is zero.<br>
# std_err:  Standard error of the estimated gradient.<br>

# %% [markdown]
# ### Displaying Regression Results

# %%
print("\nRegression Results:\n", regression_results)
# Out:
# Regression Results:
#  {'regression_1': {'slope': 0.5000909090909091, 'intercept': 3.0000909090909103, 'r_value': 0.8164205163448399, 'p_value': 0.00216962887307879, 'std_err': 0.11790550059563408}, 'regression_2': {'slope': 0.5000000000000001, 'intercept': 3.000909090909089, 'r_value': 0.816236506000243, 'p_value': 0.0021788162369107845, 'std_err': 0.11796374596764074}, 'regression_3': {'slope': 0.4997272727272729, 'intercept': 3.002454545454544, 'r_value': 0.8162867394895984, 'p_value': 0.002176305279228015, 'std_err': 0.11787766222100221}, 'regression_4': {'slope': 0.4999090909090909, 'intercept': 3.0017272727272726, 'r_value': 0.8165214368885028, 'p_value': 0.002164602347197222, 'std_err': 0.11781894172968553}}

# %% [markdown]
# ### Plotting scatter plots with regression lines

# %%
# Plotting scatter plots with regression lines
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

for i, ax in enumerate(axs.flat, 1):
    sns.scatterplot(x=df[f'x{i}'], y=df[f'y{i}'], ax=ax)

    slope = regression_results[f'regression_{i}']['slope']
    intercept = regression_results[f'regression_{i}']['intercept']

    x = np.linspace(df[f'x{i}'].min(), df[f'x{i}'].max(), 100) 
    y = slope * x + intercept

    ax.plot(x, y, color='red')
    ax.set_title(f'Dataset {i}: y = {slope:.2f}x + {intercept:.2f}')
    ax.set_xlabel(f'x{i}')
    ax.set_ylabel(f'y{i}')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Method Two

# %% [markdown]
# ### Read the Data using Pandas

# %%
dataframe = pd.read_csv("anscombe dataset.csv")

# %% [markdown]
# ### Calculating Descriptive Statistics

# %%
descriptive_stats = dataframe.describe()
descriptive_stats
# Out:
#               x1         x2         x3         x4         y1         y2  \
# count  11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean    9.000000   9.000000   9.000000   9.000000   7.500909   7.500909
# std     3.316625   3.316625   3.316625   3.316625   2.031568   2.031657
# min     4.000000   4.000000   4.000000   8.000000   4.260000   3.100000
# 25%     6.500000   6.500000   6.500000   8.000000   6.315000   6.695000
# 50%     9.000000   9.000000   9.000000   8.000000   7.580000   8.140000
# 75%    11.500000  11.500000  11.500000   8.000000   8.570000   8.950000
# max    14.000000  14.000000  14.000000  19.000000  10.840000   9.260000
#
#               y3         y4
# count  11.000000  11.000000
# mean    7.500000   7.500909
# std     2.030424   2.030579
# min     5.390000   5.250000
# 25%     6.250000   6.170000
# 50%     7.110000   7.040000
# 75%     7.980000   8.190000
# max    12.740000  12.500000

# %% [markdown]
# ### Calculating the Correlations Between the Different Variables

# %%
correlations = dataframe.corr()
correlations
# Out:
#           x1        x2        x3        x4        y1        y2        y3  \
# x1  1.000000  1.000000  1.000000 -0.500000  0.816421  0.816237  0.816287
# x2  1.000000  1.000000  1.000000 -0.500000  0.816421  0.816237  0.816287
# x3  1.000000  1.000000  1.000000 -0.500000  0.816421  0.816237  0.816287
# x4 -0.500000 -0.500000 -0.500000  1.000000 -0.529093 -0.718437 -0.344661
# y1  0.816421  0.816421  0.816421 -0.529093  1.000000  0.750005  0.468717
# y2  0.816237  0.816237  0.816237 -0.718437  0.750005  1.000000  0.587919
# y3  0.816287  0.816287  0.816287 -0.344661  0.468717  0.587919  1.000000
# y4 -0.314047 -0.314047 -0.314047  0.816521 -0.489116 -0.478095 -0.155472
#
#           y4
# x1 -0.314047
# x2 -0.314047
# x3 -0.314047
# x4  0.816521
# y1 -0.489116
# y2 -0.478095
# y3 -0.155472
# y4  1.000000

# %% [markdown]
# ### Calculate linear regression parameters for each dataset

# %%
regression_results = {} #Initialize Dictionary for Regression Results

#Perform Linear Regression for Each Dataset
for i in range(1, 5):
    slope, intercept, r_value, p_value, std_err = stats.linregress(dataframe[f'x{i}'], dataframe[f'y{i}'])
    
    regression_results[f'regression_{i}'] = {
        'slope': slope,
        'intercept': intercept,
        'r_value': r_value,
        'p_value': p_value,
        'std_err': std_err
    }

# %% [markdown]
# ### Displaying Regression Results

# %%
print("\nRegression Results:\n", regression_results)
# Out:
# Regression Results:
#  {'regression_1': {'slope': 0.5000909090909091, 'intercept': 3.0000909090909103, 'r_value': 0.8164205163448399, 'p_value': 0.00216962887307879, 'std_err': 0.11790550059563408}, 'regression_2': {'slope': 0.5000000000000001, 'intercept': 3.000909090909089, 'r_value': 0.816236506000243, 'p_value': 0.0021788162369107845, 'std_err': 0.11796374596764074}, 'regression_3': {'slope': 0.4997272727272729, 'intercept': 3.002454545454544, 'r_value': 0.8162867394895984, 'p_value': 0.002176305279228015, 'std_err': 0.11787766222100221}, 'regression_4': {'slope': 0.4999090909090909, 'intercept': 3.0017272727272726, 'r_value': 0.8165214368885028, 'p_value': 0.002164602347197222, 'std_err': 0.11781894172968553}}

# %% [markdown]
# ### Plotting scatter plots with regression lines

# %%
# Plotting scatter plots with regression lines
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

for i, ax in enumerate(axs.flat, 1):
    sns.scatterplot(x=dataframe[f'x{i}'], y=dataframe[f'y{i}'], ax=ax)

    slope = regression_results[f'regression_{i}']['slope']

    intercept = regression_results[f'regression_{i}']['intercept']

    x = np.linspace(dataframe[f'x{i}'].min(), dataframe[f'x{i}'].max(), 100)
    y = slope * x + intercept

    ax.plot(x, y, color='red')
    ax.set_title(f'Dataset {i}: y = {slope:.2f}x + {intercept:.2f}')
    ax.set_xlabel(f'x{i}')
    ax.set_ylabel(f'y{i}')

plt.tight_layout()
plt.show()
